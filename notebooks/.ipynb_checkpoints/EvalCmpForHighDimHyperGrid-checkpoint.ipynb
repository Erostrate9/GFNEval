# %%
#@title Install Dependencies
# !find . -name "*.pyc" -delete
# !find . -name "__pycache__" -delete
# !pip install --no-deps git+https://github.com/GFNOrg/torchgfn.git
# Replace with your GitHub username and personal access token
username = "xxx"
token = "xxxxx"

# Replace with your private repository URL
repo_url = "https://github.com/Erostrate9/GFNEval.git"

# !pip install --no-deps git+https://{username}:{token}@{repo_url.split('https://')[1]}#subdirectory=torchgfn
# Out:
# Collecting git+https://sdawzy:****@github.com/Erostrate9/GFNEval.git#subdirectory=torchgfn
#   Cloning https://sdawzy:****@github.com/Erostrate9/GFNEval.git to /tmp/pip-req-build-immypcy0
#   Running command git clone --filter=blob:none --quiet 'https://sdawzy:****@github.com/Erostrate9/GFNEval.git' /tmp/pip-req-build-immypcy0
#   Resolved https://sdawzy:****@github.com/Erostrate9/GFNEval.git to commit 650460ae049f91f35ee767224f2c347ab039a862
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: torchgfn
#   Building wheel for torchgfn (pyproject.toml) ... done
#   Created wheel for torchgfn: filename=torchgfn-1.1.1-py3-none-any.whl size=82803 sha256=0a90366b2adcd68b0ade3e988fbd7667ac3b28f62e7414a9a5881b8c854d9bc7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m6qp_m69/wheels/97/74/20/5c5130c3639d55c9ed0b3f7f003fa1a07cb97f41d8198db048
# Successfully built torchgfn
# Installing collected packages: torchgfn
# Successfully installed torchgfn-1.1.1

# %%
#@title Import Necessary Packages
import torch
torch.set_default_dtype(torch.float)
from torch import Tensor
from torch import nn
from torch import optim

from gfn.gflownet import GFlowNet, TBGFlowNet, SubTBGFlowNet, FMGFlowNet, DBGFlowNet
from gfn.samplers import Sampler
from gfn.env import Env
from gfn.modules import DiscretePolicyEstimator, ScalarEstimator
from gfn.utils.modules import MLP  # is a simple multi-layer perceptron (MLP)
from gfn.containers import Trajectories
from gfn.states import States

from gfn.utils.evaluation import PhiFunction, calc_KL_using_model, compute_KL
from gfn.utils.evaluation import get_random_test_set, get_sampled_test_set, evaluate_GFNEvalS, evaluate_GFNEvalS_with_monte_carlo
from gfn.gym.hypergrid2 import HyperGrid2

from tqdm import tqdm
import matplotlib.pyplot as plt

import pickle
import os
from google.colab import drive

# %%
#@title Experiment Setup, Traing, and Testing
def experiment_setup(env : Env,  algo: GFlowNet):
    gfn = None
    sampler = None
    optimizer = None

    if algo is TBGFlowNet:
        # The environment has a preprocessor attribute, which is used to preprocess the state before feeding it to the policy estimator
        module_PF = MLP(
            input_dim=env.preprocessor.output_dim,
            output_dim=env.n_actions
        ).to(env.device)  # Neural network for the forward policy, with as many outputs as there are actions
        module_PB = MLP(
            input_dim=env.preprocessor.output_dim,
            output_dim=env.n_actions - 1,
            trunk=module_PF.trunk  # We share all the parameters of P_F and P_B, except for the last layer
        ).to(env.device)

        pf_estimator = DiscretePolicyEstimator(module_PF, env.n_actions, is_backward=False, preprocessor=env.preprocessor).to(env.device)
        pb_estimator = DiscretePolicyEstimator(module_PB, env.n_actions, is_backward=True, preprocessor=env.preprocessor).to(env.device)

        gfn = TBGFlowNet(logZ=0., pf=pf_estimator, pb=pb_estimator).to(env.device)

        sampler = Sampler(estimator=pf_estimator)

        optimizer = torch.optim.Adam(gfn.pf_pb_parameters(), lr=1e-3)
        optimizer.add_param_group({"params": gfn.logz_parameters(), "lr": 1e-1})

    if algo is SubTBGFlowNet:
        # The environment has a preprocessor attribute, which is used to preprocess the state before feeding it to the policy estimator
        module_PF = MLP(
            input_dim=env.preprocessor.output_dim,
            output_dim=env.n_actions
        ).to(env.device)  # Neural network for the forward policy, with as many outputs as there are actions

        module_PB = MLP(
            input_dim=env.preprocessor.output_dim,
            output_dim=env.n_actions - 1,
            trunk=module_PF.trunk  # We share all the parameters of P_F and P_B, except for the last layer
        ).to(env.device)
        module_logF = MLP(
            input_dim=env.preprocessor.output_dim,
            output_dim=1,  # Important for ScalarEstimators!
        ).to(env.device)

        # 3 - We define the estimators.
        pf_estimator = DiscretePolicyEstimator(module_PF, env.n_actions, is_backward=False, preprocessor=env.preprocessor).to(env.device)
        pb_estimator = DiscretePolicyEstimator(module_PB, env.n_actions, is_backward=True, preprocessor=env.preprocessor).to(env.device)
        logF_estimator = ScalarEstimator(module=module_logF, preprocessor=env.preprocessor).to(env.device)

        # 4 - We define the GFlowNet.
        gfn = SubTBGFlowNet(pf=pf_estimator, pb=pb_estimator, logF=logF_estimator, lamda=0.9).to(env.device)

        # 5 - We define the sampler and the optimizer.
        sampler = Sampler(estimator=pf_estimator)  # We use an on-policy sampler, based on the forward policy

        # Different policy parameters can have their own LR.
        # Log F gets dedicated learning rate (typically higher).
        optimizer = torch.optim.Adam(gfn.pf_pb_parameters(), lr=1e-3)
        optimizer.add_param_group({"params": gfn.logF_parameters(), "lr": 1e-2})

    # TODO: initialize parameterizations of FMGFlowNet and DBGFlowNet

    return gfn, sampler, optimizer

def training(gfn: GFlowNet, sample: Sampler, optimizer, num_epochs: int = 1000) -> Sampler:
    for i in (pbar := tqdm(range(num_epochs))):
        trajectories = sampler.sample_trajectories(env=env, n=16)
        optimizer.zero_grad()
        loss = gfn.loss(env, trajectories)
        loss.backward()
        optimizer.step()
        if i % 25 == 0:
            pbar.set_postfix({"loss": loss.item()})
    return sampler

def eval_kl(env: Env, gfn: GFlowNet, num_samples: int = 10000, num_epochs: int = 250, show_progress: bool = False) -> None:
    # Sample from proxy distribution
    # i.e. from the learned sampler
    samples_proxy_distribution = gfn.sample_terminating_states(env=env, n=num_samples)
    samples_proxy_tensor = samples_proxy_distribution.tensor.double().to(env.device)

    # Sample from the true distribution
    samples_true_distribution = env.sample_states_from_distribution(num_samples)
    samples_true_tensor = samples_true_distribution.tensor.double().to(env.device)

    kl, phi = compute_KL(samples_proxy_tensor, samples_true_tensor,
                         num_epochs=num_epochs, show_progress=show_progress,
                         device=env.device)
    return kl, phi

# %%
#@title Some test
env = HyperGrid2(ndim=4, height=256, ncenters=4,
                             seed=torch.randint(0, 10000, (1,)).item(),
                             device_str='cpu')
sampler = results[(4,256,4)]['sampler']
sampler.sample_trajectories(env=env, n=10)

# %% [markdown]
# Start experiments from here:

# %%
# Experiment Setup
ndim = 10
height = 10
ncenter = 10
num_epochs = 1000
n_samples_kl = 10000
n_samples_monte_carlo = 100000
device_str = torch.device("cuda" if torch.cuda.is_available() else "cpu")
algo = TBGFlowNet
# seed = torch.randint(0, 10000, (1,)).item()
seed = 19260817
env = HyperGrid2(ndim=ndim, height=height, ncenters=ncenter,
                  seed=seed,
                  device_str=device_str)
gfn, sampler, optimizer = experiment_setup(env, algo)

results = []

# Start training
for i in (pbar := tqdm(range(num_epochs))):
    trajectories = sampler.sample_trajectories(env=env, n=16)
    optimizer.zero_grad()
    loss = gfn.loss(env, trajectories)
    loss.backward()
    optimizer.step()
    if i % 25 == 0:
        # estimate empirical kl
        kl, phi = eval_kl(env, gfn)
        # estimate spearnman correlation
        test_states_sample, test_rewards_sample = get_sampled_test_set(gfn, env, n=n_samples)
        spearman, _, _ = evaluate_GFNEvalS_with_monte_carlo(gfn, env, test_states_sample,
                                                      test_rewards_sample, n_samples=n_samples_monte_carlo, show_progress=False)
        results.append({
            "epoch": i,
            "loss": loss.item(),
            "kl": kl,
            "spearman": spearman,
            "phi": phi
        })
        pbar.set_postfix({"loss": loss.item(), "kl": kl, "spearman": spearman})
# Out:
#   0%|          | 2/1000 [00:36<4:09:10, 14.98s/it, loss=520, kl=tensor(126.2148, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.845]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 10.5861 seconds
#   3%|▎         | 26/1000 [01:24<3:32:04, 13.06s/it, loss=125, kl=tensor(5.7373, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.399]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 13.0129 seconds
#   5%|▌         | 51/1000 [02:14<3:28:39, 13.19s/it, loss=88.3, kl=tensor(4.0536, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.159]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 13.0223 seconds
#   8%|▊         | 76/1000 [03:03<3:22:41, 13.16s/it, loss=8.84, kl=tensor(3.2751, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.0749]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 13.1103 seconds
#  10%|█         | 101/1000 [03:51<3:14:15, 12.97s/it, loss=7.43, kl=tensor(2.3065, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0103]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 13.1191 seconds
#  13%|█▎        | 126/1000 [04:38<3:02:05, 12.50s/it, loss=8.05, kl=tensor(2.7017, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.00536]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.4045 seconds
#  15%|█▌        | 151/1000 [05:24<2:55:51, 12.43s/it, loss=10.4, kl=tensor(3.1504, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.00752]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.2321 seconds
#  18%|█▊        | 175/1000 [05:29<03:10,  4.32it/s, loss=10.4, kl=tensor(3.1504, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.00752]/usr/local/lib/python3.10/dist-packages/gfn/utils/evaluation.py:254: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   spearman_corr_monte_carlo, _ = spearmanr(log_probs_monte_carlo, log_rewards)
#  18%|█▊        | 176/1000 [06:10<2:53:20, 12.62s/it, loss=7.73, kl=tensor(2.3907, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.6505 seconds
#  20%|██        | 201/1000 [06:55<2:40:00, 12.02s/it, loss=10.3, kl=tensor(3.4381, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.000534]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 11.7505 seconds
#  23%|██▎       | 226/1000 [07:41<2:42:54, 12.63s/it, loss=17.3, kl=tensor(2.4619, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0188]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.2777 seconds
#  25%|██▌       | 252/1000 [08:27<1:49:14,  8.76s/it, loss=8.71, kl=tensor(2.2796, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.017]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.9209 seconds
#  28%|██▊       | 276/1000 [09:12<2:27:18, 12.21s/it, loss=6.12, kl=tensor(2.4822, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0123]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.2556 seconds
#  30%|███       | 301/1000 [09:57<2:22:40, 12.25s/it, loss=5.26, kl=tensor(2.5272, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0158]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.2721 seconds
#  33%|███▎      | 326/1000 [10:42<2:17:06, 12.21s/it, loss=2.51, kl=tensor(2.2896, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0245]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3818 seconds
#  35%|███▌      | 352/1000 [11:27<1:32:40,  8.58s/it, loss=4.12, kl=tensor(2.5450, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0145]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.2017 seconds
#  38%|███▊      | 377/1000 [12:15<1:34:18,  9.08s/it, loss=5.2, kl=tensor(2.0128, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.00606]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.9956 seconds
#  40%|████      | 401/1000 [12:59<2:01:34, 12.18s/it, loss=3.11, kl=tensor(2.1625, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.00904]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.1713 seconds
#  43%|████▎     | 426/1000 [13:45<1:57:58, 12.33s/it, loss=5.03, kl=tensor(2.1912, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0188]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.4932 seconds
#  45%|████▌     | 451/1000 [14:30<1:52:41, 12.32s/it, loss=3.48, kl=tensor(1.9323, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.0165]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.6746 seconds
#  48%|████▊     | 477/1000 [15:15<1:15:26,  8.65s/it, loss=3.03, kl=tensor(1.7918, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.00516]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3064 seconds
#  50%|█████     | 501/1000 [16:01<1:44:30, 12.57s/it, loss=5.27, kl=tensor(1.7712, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0139]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.5157 seconds
#  53%|█████▎    | 526/1000 [16:46<1:37:27, 12.34s/it, loss=3.27, kl=tensor(1.9541, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.000426]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.4743 seconds
#  55%|█████▌    | 551/1000 [17:32<1:33:05, 12.44s/it, loss=3.5, kl=tensor(1.7060, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.5124 seconds
#  58%|█████▊    | 576/1000 [18:20<1:30:49, 12.85s/it, loss=2.52, kl=tensor(1.8051, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.8103 seconds
#  60%|██████    | 601/1000 [19:05<1:22:26, 12.40s/it, loss=3.04, kl=tensor(1.7013, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3946 seconds
#  63%|██████▎   | 626/1000 [19:51<1:17:25, 12.42s/it, loss=2.76, kl=tensor(1.5465, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.5681 seconds
#  65%|██████▌   | 651/1000 [20:36<1:10:51, 12.18s/it, loss=2.95, kl=tensor(1.6389, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0236]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3208 seconds
#  68%|██████▊   | 676/1000 [21:22<1:06:01, 12.23s/it, loss=7.57, kl=tensor(1.6778, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0151]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3258 seconds
#  70%|███████   | 701/1000 [22:08<1:02:56, 12.63s/it, loss=4.14, kl=tensor(1.3981, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.9563 seconds
#  73%|███████▎  | 726/1000 [22:54<56:57, 12.47s/it, loss=3.79, kl=tensor(1.3375, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0133]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.5487 seconds
#  75%|███████▌  | 751/1000 [23:41<52:28, 12.64s/it, loss=1.69, kl=tensor(1.3815, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.017]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.7601 seconds
#  78%|███████▊  | 776/1000 [24:26<45:48, 12.27s/it, loss=6.59, kl=tensor(1.6727, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.0145]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.5907 seconds
#  80%|████████  | 801/1000 [25:11<40:26, 12.19s/it, loss=5.65, kl=tensor(1.5370, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3105 seconds
#  83%|████████▎ | 826/1000 [25:57<35:45, 12.33s/it, loss=4.74, kl=tensor(1.5822, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=0.00878]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.4866 seconds
#  85%|████████▌ | 851/1000 [26:42<30:27, 12.26s/it, loss=2.19, kl=tensor(1.4551, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.4838 seconds
#  88%|████████▊ | 876/1000 [27:27<25:14, 12.21s/it, loss=1.31, kl=tensor(1.3628, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=-0.000176]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 11.9469 seconds
#  90%|█████████ | 901/1000 [28:13<20:33, 12.46s/it, loss=4.8, kl=tensor(1.4848, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.2472 seconds
#  93%|█████████▎| 927/1000 [28:59<10:33,  8.68s/it, loss=3.26, kl=tensor(1.3352, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3771 seconds
#  95%|█████████▌| 951/1000 [29:44<10:09, 12.43s/it, loss=3.32, kl=tensor(1.3022, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.4344 seconds
#  98%|█████████▊| 976/1000 [30:30<04:52, 12.19s/it, loss=4.35, kl=tensor(1.1872, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]
# Function 'evaluate_GFNEvalS_with_monte_carlo' executed in 12.3095 seconds
# 100%|██████████| 1000/1000 [30:35<00:00,  1.84s/it, loss=4.35, kl=tensor(1.1872, dtype=torch.float64, grad_fn=<SubBackward0>), spearman=nan]

# %% [markdown]
# Plot the results

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract data
epochs = [item["epoch"] for item in results]
loss = [item["loss"] for item in results]
kl = [item["kl"].detach() for item in results]
spearman = [item["spearman"] for item in results]

# Plot each metric
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Loss', marker='o')
plt.plot(epochs, kl, label='KL', marker='s')
plt.plot(epochs, spearman, label='Spearman', marker='^')

plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Metrics Over Epochs')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np

# Apply log transformation
log_loss = [np.log(val) for val in loss]
log_kl = [np.log(val) for val in kl]
# log_spearman = [np.log(val) for val in spearman]

plt.figure(figsize=(10, 6))
plt.plot(epochs, log_loss, label='Log Loss', marker='o')
plt.plot(epochs, log_kl, label='Log KL', marker='s')
# plt.plot(epochs, log_spearman, label='Log Spearman', marker='^')

plt.xlabel('Epoch')
plt.ylabel('Log Value')
plt.title('Logarithmic Metrics for Loss and KL')
plt.legend()
plt.grid()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 8))
axes = axes.flatten()

metrics = {"Loss": loss, "KL": kl, "Spearman": spearman}
for ax, (name, values) in zip(axes, metrics.items()):
    ax.plot(epochs, values, marker='o')
    ax.set_title(name)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Value')
    ax.grid()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 8))
axes = axes.flatten()

log_metrics = {"Log Loss": log_loss, "Log KL": log_kl}
for ax, (name, values) in zip(axes, log_metrics.items()):
    ax.plot(epochs, values, marker='o')
    ax.set_title(name)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Log Value')
    ax.grid()

plt.tight_layout()
plt.show()
